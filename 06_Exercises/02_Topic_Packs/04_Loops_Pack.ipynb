# %% [markdown]
# # Loops Pack
#
# Source: `04_Loops_Pack.md`

# %% [markdown]
# ## Lo1: Print 1 to 5
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# # expected: 1 2 3 4 5
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo2: Sum 1 to 5
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# # expected: 15
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo3: Count Evens
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# nums = [1,2,3,4]
# # expected: 2
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo4: Find First > 10
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# nums = [3, 8, 12, 5]
# # expected: 12
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo5: While Countdown
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# # expected: 3 2 1
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo6: Loop over String
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# text = "abc"
# # expected: a b c
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo7: Skip Negatives
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# nums = [1,-2,3]
# # expected: 1 3
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo8: Nested Loop
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# # expected: pairs (1,1),(1,2),(2,1),(2,2)
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo9: Build Squares
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# # expected: [1,4,9]
# ```

# %%
# Write your solution here

# %% [markdown]
# ## Lo10: Stop at 7
# **Task:** Solve the task below.
# **Starter Code:**
# ```python
# nums = [3,5,7,9]
# # expected: 3 5
# ```

# %%
# Write your solution here
